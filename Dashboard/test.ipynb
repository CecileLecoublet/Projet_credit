# %%
import pandas as pd

# %%
pd.read_csv("X_train_scaled.csv")
# Out:
#      SK_ID_CURR  NAME_CONTRACT_TYPE  CODE_GENDER  FLAG_OWN_CAR  \
# 0     -0.340398           -0.324395    -0.720370      1.392925
# 1     -1.618859           -0.324395     1.388015     -0.717914
# 2     -1.003245           -0.324395     1.388015      1.392925
# 3      0.914160           -0.324395     1.388015      1.392925
# 4      0.926466           -0.324395     1.388015     -0.717914
# ..          ...                 ...          ...           ...
# 995    1.691570           -0.324395    -0.720370     -0.717914
# 996    0.818713           -0.324395    -0.720370     -0.717914
# 997   -0.711280           -0.324395     1.388015     -0.717914
# 998    0.528110           -0.324395    -0.720370     -0.717914
# 999   -1.663532           -0.324395    -0.720370     -0.717914
#
#      FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0          -1.504820     -0.577538          0.009287   -0.108706    -0.741162
# ...

# %%
nom = pd.read_csv("nom.csv")
nom[nom["SK_ID_CURR"] == 111196]
# Out:
#      Unnamed: 0  SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 998        1569      111196         Cash loans           M            N
#
#     FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 998               Y             0          135000.0    224136.0      17707.5
#
#      ...  FLAG_DOCUMENT_19 FLAG_DOCUMENT_20 FLAG_DOCUMENT_21  \
# 998  ...                 0                0                0
#
#     AMT_REQ_CREDIT_BUREAU_HOUR AMT_REQ_CREDIT_BUREAU_DAY  \
# 998                        0.0                       0.0
#
#     AMT_REQ_CREDIT_BUREAU_WEEK  AMT_REQ_CREDIT_BUREAU_MON  \
# 998                        0.0                        0.0
#
#      AMT_REQ_CREDIT_BUREAU_QRT  AMT_REQ_CREDIT_BUREAU_YEAR  \
# 998                        0.0                         2.0
#
#      DAYS_EMPLOYED_OUTLIERS
# 998                   False
#
# [1 rows x 123 columns]

# %%
test = nom[nom["SK_ID_CURR"] == 111196]

# %%
test["OCCUPATION_TYPE"]
# Out:
# 998    Laborers
# Name: OCCUPATION_TYPE, dtype: object
